# %%
import crud
from utilities import car_sale, get_input
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ind_project

# %%
ind_project.get_data()
# Out:
#                  Make         Model  ColorID VehicleType  CostPrice  \
# StockID
# 1         Rolls Royce      Camargue        1      Saloon      50000
# 2        Aston Martin           DBS        2       Coupe      75000
# 3         Rolls Royce  Silver Ghost        3      Saloon      75000
# 4         Rolls Royce  Silver Ghost        2      Saloon      88000
# 5         Rolls Royce      Camargue        5      Saloon      62000
# ...               ...           ...      ...         ...        ...
# 457      Aston Martin           DB9        7       Coupe      27500
# 458      Aston Martin           DB9        1       Coupe      22500
# 459       Rolls Royce      Camargue        2      Saloon      22500
# 460      Aston Martin           DB9        3       Coupe      36125
# 461      Aston Martin           DB9        4       Coupe      22500
#
#          SpareParts  LaborCost Registration_Date  Mileage PurchaseDate
# StockID
# ...

# %%
ind_project.get_max_costPrice()
# Out:
# 160000

# %%
ind_project.get_min_costPrice()
# Out:
# 4500

# %% [markdown]
# group by make
# find average cost price for each make

# %%
ind_project.get_mean_costprice_for_makes()
# Out:
#                  CostPrice
# Make
# Aston Martin  60952.454545
# Bentley       44158.333333
# Jaguar        37982.170543
# MGB            9500.000000
# Rolls Royce   65336.904762
# TVR           40833.333333
# Triumph       18208.333333

# %% [markdown]
# group by model
# find average cost price for each model

# %%
ind_project().get_mean_costprice_for_models()
# Out:
#                    CostPrice
# Model
# Arnage          28200.000000
# Azure           28200.000000
# Camargue        61002.692308
# Cerbera         40000.000000
# Continental     48900.000000
# DB4             84167.500000
# DB7             23703.125000
# DB9             59132.962963
# DBS             68000.000000
# GT               9500.000000
# Phantom         64500.000000
# Rapide         142500.000000
# Silver Ghost    75630.000000
# Silver Seraph   71445.000000
# Silver Shadow   71445.000000
# TR4             18270.833333
# TR5             19500.000000
# TR7             15250.000000
# Turbo R         35460.000000
# Tuscan          41136.363636
# Vanquish        89700.000000
# Vantage         38750.000000
# Wraith          64500.000000
# XJ12            33750.000000
# XJ6             32630.769231
# XK              39803.157895
# Zagato         127500.000000

# %% [markdown]
# return a dataframe were make matches user provided sting

# %%
ind_project.get_group_of_makes()
# Out:
#             Make        Model  ColorID  VehicleType  CostPrice  SpareParts  \
# StockID
# 64       Bentley  Continental        2       Saloon      25700        2570
# 65       Bentley       Arnage        2       Saloon      25700        2570
# 66       Bentley        Azure        1       Saloon      25700        2570
# 67       Bentley      Turbo R        1       Saloon      25700        2570
# 68       Bentley  Continental        5        Coupe      62000        2570
# ...          ...          ...      ...          ...        ...         ...
# 391      Bentley  Continental        9        Coupe      67000        2570
# 392      Bentley  Continental        8       Saloon      67000        2570
# 393      Bentley  Continental        7       Saloon      67000        2570
# 394      Bentley  Continental        6       Saloon      30700        2570
# 395      Bentley  Continental        5  Convertible      30700        2570
#
#          LaborCost Registration_Date  Mileage PurchaseDate
# ...

# %% [markdown]
# return a dataframe were model matches user provided sting

# %%
ind_project.get_group_of_makes_and_models()
# Out:
# Empty DataFrame
# Columns: [Make, Model, ColorID, VehicleType, CostPrice, SpareParts, LaborCost, Registration_Date, Mileage, PurchaseDate]
# Index: []

# %% [markdown]
# group by mileage
# find average labor cost

# %%
ind_project.labor_cost_grouped_by_mileage()
# Out:
#            LaborCost
# Mileage
# 7500      654.000000
# 8000      570.000000
# 9850      987.000000
# 9950      750.000000
# 15000     895.000000
# 16525    1250.000000
# 17000    1250.000000
# 17500     658.000000
# 18695    1250.000000
# 28750     651.363636
# 33000    1250.000000
# 52000    1125.862069
# 52500     589.857143
# 61000    1250.000000
# 65250     417.833333
# 67000    1250.000000
# 75000     616.666667
# 127220    653.666667
# 161000   1250.000000

# %% [markdown]
# group by model
# find average labor cost for each model

# %%
ind_project.labor_cost_grouped_by_make_and_model()

# %% [markdown]
# sort the datafram based on registrationDate
# then plot the cost price

# %%
#change the dtype of registration date to datetime64
df = df.astype({"Registration_Date": "datetime64[ns]"})
sorted_df = df.sort_values(by=["Registration_Date"], ascending=True)
#plot the data, registration_date is the x-axis, CostPrice is the y-axis
plt.plot(sorted_df["Registration_Date"], sorted_df["LaborCost"])
plt.xlabel("Registration Date")
plt.ylabel("Labor cost")
plt.show()

# %%
ind_project.new_car_sale()
# Out:
#                  Make         Model  ColorID VehicleType  CostPrice  \
# StockID
# 1         Rolls Royce      Camargue        1      Saloon      50000
# 2        Aston Martin           DBS        2       Coupe      75000
# 3         Rolls Royce  Silver Ghost        3      Saloon      75000
# 4         Rolls Royce  Silver Ghost        2      Saloon      88000
# 5         Rolls Royce      Camargue        5      Saloon      62000
# ...               ...           ...      ...         ...        ...
# 459       Rolls Royce      Camargue        2      Saloon      22500
# 460      Aston Martin           DB9        3       Coupe      36125
# 461      Aston Martin           DB9        4       Coupe      22500
# 476                 q             q        3           3          3
# 477                 4             4        4           4          4
#
#          SpareParts  LaborCost Registration_Date  Mileage PurchaseDate
# StockID
# ...

# %%
ind_project.del_car_sales()
# Out:
#                  Make         Model  ColorID VehicleType  CostPrice  \
# StockID
# 1         Rolls Royce      Camargue        1      Saloon      50000
# 2        Aston Martin           DBS        2       Coupe      75000
# 3         Rolls Royce  Silver Ghost        3      Saloon      75000
# 4         Rolls Royce  Silver Ghost        2      Saloon      88000
# 5         Rolls Royce      Camargue        5      Saloon      62000
# ...               ...           ...      ...         ...        ...
# 457      Aston Martin           DB9        7       Coupe      27500
# 458      Aston Martin           DB9        1       Coupe      22500
# 459       Rolls Royce      Camargue        2      Saloon      22500
# 460      Aston Martin           DB9        3       Coupe      36125
# 461      Aston Martin           DB9        4       Coupe      22500
#
#          SpareParts  LaborCost Registration_Date  Mileage PurchaseDate
# StockID
# ...

# %%
ind_project.update_car_sale()
# Out:
#                  Make         Model  ColorID VehicleType  CostPrice  \
# StockID
# 1         Rolls Royce      Camargue        1      Saloon      50000
# 2        Aston Martin           DBS        2       Coupe      75000
# 3         Rolls Royce  Silver Ghost        3      Saloon      75000
# 4         Rolls Royce  Silver Ghost        2      Saloon      88000
# 5         Rolls Royce      Camargue        5      Saloon      62000
# ...               ...           ...      ...         ...        ...
# 459       Rolls Royce      Camargue        2      Saloon      22500
# 460      Aston Martin           DB9        3       Coupe      36125
# 461      Aston Martin           DB9        4       Coupe      22500
# 476                 q             q        3           3          3
# 477                 2             2        2           2          2
#
#          SpareParts  LaborCost Registration_Date  Mileage PurchaseDate
# StockID
# ...
